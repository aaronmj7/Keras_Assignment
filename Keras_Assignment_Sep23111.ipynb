# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronmj7/Keras_Assignment/blob/main/Keras_Assignment_Sep23111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Applied Data Science 2 - Keras Assignment - 2023A
#
# In this assignment you will be building a script to classify images of animals. The assignment is broken up into sections and you need to complete each section successively. The sections are:
#
# 1. Data Processing
# 2. Model Definition
# 3. Model Training
# 4. Model Evaluation
#
# In addition to this coding exercise, you will also need to write a 1-2 page report analysing and critically evaluating you models results.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Processing

# %%
# CodeGrade Tag DataProc

label_dict = {'cat' : 0,
              'dog' : 1,
              'wild' : 2}

# This function is provided to read in the image files from the folder on your
# Google Drive
def parse_image(filename):
  parts = tf.strings.split(filename, os.sep)
  label = parts[-2]
  label = tf.strings.to_number(label)

  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

img_loc = "/content/drive/MyDrive/Animals/"

train_list_ds = tf.data.Dataset.list_files(img_loc + "train/*/*")
valid_list_ds = tf.data.Dataset.list_files(img_loc + "val/*/*")

# %% [markdown]
# **Create a function called "img_process" converts the images to float32 datatype and resizes them to 64x64 pixels.**

# %%
# CodeGrade Tag Ex1a
### Write a function called img_process, which takes in the image and label as
### inputs, converts the data type of the image to tf.float32, resizes the
### image to (64,64), and finally returns the image and labels.

def img_process(image, label):
  image = tf.cast(image, tf.float32)
  image = tf.image.resize(image, [64, 64])
  return image, label

# %% [markdown]
# **Using the tf.data API, load in the training and validation data. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1b
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 128. Use techniques like caching and
### prefetching to efficiently load the data.

train_ds = (train_list_ds
                 .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
                 .batch(128)
                 .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
                 .cache()
                 .prefetch(tf.data.AUTOTUNE))

valid_ds = (train_list_ds
                 .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
                 .batch(128)
                 .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
                 .cache()
                 .prefetch(tf.data.AUTOTUNE))

# %% [markdown]
# # Model Definition
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture show in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a SoftMax activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 363146 (1.39 MB)
# Trainable params: 363146 (1.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

input = keras.layers.Input((64, 64, 3), dtype='float32', name='Input')
conv0 = keras.layers.Conv2D(16, kernel_size=(5,5), strides=(2,2),
                            padding='same', activation='relu',
                            name='Conv0')(input)
conv1 = keras.layers.Conv2D(32, kernel_size=(3,3), strides=(1,1),
                            padding='same', activation='relu',
                            name='Conv1')(conv0)
conv2 = keras.layers.Conv2D(32, kernel_size=(3,3), strides=(1,1),
                            padding='same', activation='relu',
                            name='Conv2')(conv1)
pool1 = keras.layers.MaxPool2D(pool_size=(2,2), name='Pool1')(conv2)
conv3 = keras.layers.Conv2D(64, kernel_size=(3,3), strides=(1,1),
                            padding='same', activation='relu',
                            name='Conv3')(pool1)
conv4 = keras.layers.Conv2D(64, kernel_size=(3,3), strides=(1,1),
                            padding='same', activation='relu',
                            name='Conv4')(conv3)
pool2 = keras.layers.MaxPool2D(pool_size=(2,2), name='Pool2')(conv4)
conv5 = keras.layers.Conv2D(128, kernel_size=(3,3), strides=(1,1),
                            padding='same', activation='relu',
                            name='Conv5')(pool2)
conv6 = keras.layers.Conv2D(128, kernel_size=(3,3), strides=(1,1),
                            padding='same', activation='relu',
                            name='Conv6')(conv5)
globalpool = keras.layers.GlobalAveragePooling2D(name='GlobalPool')(conv6)
dense1 = keras.layers.Dense(512, activation='relu', name='FC1')(globalpool)
dense2 = keras.layers.Dense(3, activation='softmax', name='Output')(dense1)

model = keras.models.Model(inputs=input, outputs=dense2, name='model')

# %%
# CodeGrade Tag Ex2b
### Print the model summary and confirm is has the same architecture as the one
### provided.

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 3)                 1539
#
# =================================================================
# Total params: 359555 (1.37 MB)
# Trainable params: 359555 (1.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile the model using the Adam Optimizer with a learning rate of ```5e-5```, ```sparse categorical crossentropy``` loss function, and ```accuracy``` metric.**

# %%
# CodeGrade Tag Ex2c

model.compile(optimizer=keras.optimizers.Adam(learning_rate=5e-5),
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics='accuracy')

# %% [markdown]
# # Model Training
#
# **Create a Model Checkpoint Callback that saves the weights of the best performing epoch, based on the validation accuracy.**

# %%
# CodeGrade Tag Ex3a
### Create a ModelCheckpoint callback to store the bext weights from the model,
### based on the validation accuracy. Call this callback "checkpoint_callback"

checkpoint_filepath = '/content/drive/MyDrive/model_weights.h5'

checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                      save_weights_only=True,
                                      monitor='val_accuracy',
                                      mode='max', save_best_only=True,
                                      verbose=1)

# %% [markdown]
# **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3b
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.01)

lr_callback = LearningRateScheduler(scheduler)

# %% [markdown]
# **Train the model for 100 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3c
### Train the model for 100 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

history = model.fit(train_ds, epochs=100,
                    callbacks=[checkpoint_callback, lr_callback],
                    validation_data=valid_ds)
# Out:
# Epoch 1/100
# 115/115 [==============================] - ETA: 0s - loss: 1.0042 - accuracy: 0.4989
# Epoch 1: val_accuracy improved from -inf to 0.64042, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 1683s 15s/step - loss: 1.0042 - accuracy: 0.4989 - val_loss: 0.7993 - val_accuracy: 0.6404 - lr: 5.0000e-05
# Epoch 2/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.7570 - accuracy: 0.6599
# Epoch 2: val_accuracy improved from 0.64042 to 0.69913, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 24ms/step - loss: 0.7543 - accuracy: 0.6616 - val_loss: 0.6882 - val_accuracy: 0.6991 - lr: 5.0000e-05
# Epoch 3/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.7277
# Epoch 3: val_accuracy improved from 0.69913 to 0.76591, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 22ms/step - loss: 0.6281 - accuracy: 0.7278 - val_loss: 0.5689 - val_accuracy: 0.7659 - lr: 5.0000e-05
# Epoch 4/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.5633 - accuracy: 0.7592
# Epoch 4: val_accuracy improved from 0.76591 to 0.79892, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.5614 - accuracy: 0.7605 - val_loss: 0.5003 - val_accuracy: 0.7989 - lr: 5.0000e-05
# Epoch 5/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.5042 - accuracy: 0.7900
# Epoch 5: val_accuracy improved from 0.79892 to 0.82599, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 19ms/step - loss: 0.5037 - accuracy: 0.7907 - val_loss: 0.4479 - val_accuracy: 0.8260 - lr: 5.0000e-05
# Epoch 6/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.8148
# Epoch 6: val_accuracy improved from 0.82599 to 0.84512, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.4578 - accuracy: 0.8153 - val_loss: 0.4045 - val_accuracy: 0.8451 - lr: 5.0000e-05
# Epoch 7/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.4190 - accuracy: 0.8347
# Epoch 7: val_accuracy improved from 0.84512 to 0.86132, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.4187 - accuracy: 0.8349 - val_loss: 0.3672 - val_accuracy: 0.8613 - lr: 5.0000e-05
# Epoch 8/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.3792 - accuracy: 0.8543
# Epoch 8: val_accuracy improved from 0.86132 to 0.87718, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.3790 - accuracy: 0.8542 - val_loss: 0.3330 - val_accuracy: 0.8772 - lr: 5.0000e-05
# Epoch 9/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.3480 - accuracy: 0.8673
# Epoch 9: val_accuracy improved from 0.87718 to 0.88579, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 22ms/step - loss: 0.3473 - accuracy: 0.8675 - val_loss: 0.3085 - val_accuracy: 0.8858 - lr: 5.0000e-05
# Epoch 10/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3190 - accuracy: 0.8812
# Epoch 10: val_accuracy improved from 0.88579 to 0.89420, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.3188 - accuracy: 0.8814 - val_loss: 0.2865 - val_accuracy: 0.8942 - lr: 5.0000e-05
# Epoch 11/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.8908
# Epoch 11: val_accuracy improved from 0.89420 to 0.90377, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2959 - accuracy: 0.8909 - val_loss: 0.2631 - val_accuracy: 0.9038 - lr: 4.9502e-05
# Epoch 12/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2780 - accuracy: 0.8983
# Epoch 12: val_accuracy improved from 0.90377 to 0.91368, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2776 - accuracy: 0.8984 - val_loss: 0.2441 - val_accuracy: 0.9137 - lr: 4.9010e-05
# Epoch 13/100
# 111/115 [===========================>..] - ETA: 0s - loss: 0.2648 - accuracy: 0.9029
# Epoch 13: val_accuracy improved from 0.91368 to 0.91819, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2633 - accuracy: 0.9039 - val_loss: 0.2344 - val_accuracy: 0.9182 - lr: 4.8522e-05
# Epoch 14/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9070
# Epoch 14: val_accuracy did not improve from 0.91819
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2539 - accuracy: 0.9074 - val_loss: 0.2382 - val_accuracy: 0.9128 - lr: 4.8039e-05
# Epoch 15/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.2433 - accuracy: 0.9109
# Epoch 15: val_accuracy did not improve from 0.91819
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2420 - accuracy: 0.9114 - val_loss: 0.2259 - val_accuracy: 0.9176 - lr: 4.7561e-05
# Epoch 16/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.2354 - accuracy: 0.9123
# Epoch 16: val_accuracy improved from 0.91819 to 0.92632, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2355 - accuracy: 0.9124 - val_loss: 0.2052 - val_accuracy: 0.9263 - lr: 4.7088e-05
# Epoch 17/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2371 - accuracy: 0.9130
# Epoch 17: val_accuracy did not improve from 0.92632
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2366 - accuracy: 0.9129 - val_loss: 0.2067 - val_accuracy: 0.9250 - lr: 4.6620e-05
# Epoch 18/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2324 - accuracy: 0.9140
# Epoch 18: val_accuracy did not improve from 0.92632
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2317 - accuracy: 0.9141 - val_loss: 0.2257 - val_accuracy: 0.9159 - lr: 4.6156e-05
# Epoch 19/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2184 - accuracy: 0.9201
# Epoch 19: val_accuracy did not improve from 0.92632
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2177 - accuracy: 0.9202 - val_loss: 0.2203 - val_accuracy: 0.9178 - lr: 4.5697e-05
# Epoch 20/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2102 - accuracy: 0.9229
# Epoch 20: val_accuracy did not improve from 0.92632
# 115/115 [==============================] - 2s 20ms/step - loss: 0.2095 - accuracy: 0.9230 - val_loss: 0.2149 - val_accuracy: 0.9195 - lr: 4.5242e-05
# Epoch 21/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.2031 - accuracy: 0.9261
# Epoch 21: val_accuracy did not improve from 0.92632
# 115/115 [==============================] - 2s 21ms/step - loss: 0.2023 - accuracy: 0.9263 - val_loss: 0.2066 - val_accuracy: 0.9224 - lr: 4.4792e-05
# Epoch 22/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.1956 - accuracy: 0.9286
# Epoch 22: val_accuracy did not improve from 0.92632
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1955 - accuracy: 0.9286 - val_loss: 0.2001 - val_accuracy: 0.9243 - lr: 4.4346e-05
# Epoch 23/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9310
# Epoch 23: val_accuracy improved from 0.92632 to 0.92878, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 24ms/step - loss: 0.1894 - accuracy: 0.9312 - val_loss: 0.1923 - val_accuracy: 0.9288 - lr: 4.3905e-05
# Epoch 24/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1848 - accuracy: 0.9334
# Epoch 24: val_accuracy improved from 0.92878 to 0.93234, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1841 - accuracy: 0.9336 - val_loss: 0.1848 - val_accuracy: 0.9323 - lr: 4.3468e-05
# Epoch 25/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1793 - accuracy: 0.9353
# Epoch 25: val_accuracy improved from 0.93234 to 0.93507, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1786 - accuracy: 0.9355 - val_loss: 0.1779 - val_accuracy: 0.9351 - lr: 4.3035e-05
# Epoch 26/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1748 - accuracy: 0.9369
# Epoch 26: val_accuracy improved from 0.93507 to 0.93760, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1741 - accuracy: 0.9372 - val_loss: 0.1728 - val_accuracy: 0.9376 - lr: 4.2607e-05
# Epoch 27/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1709 - accuracy: 0.9386
# Epoch 27: val_accuracy improved from 0.93760 to 0.93910, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 22ms/step - loss: 0.1702 - accuracy: 0.9389 - val_loss: 0.1672 - val_accuracy: 0.9391 - lr: 4.2183e-05
# Epoch 28/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.1679 - accuracy: 0.9393
# Epoch 28: val_accuracy improved from 0.93910 to 0.94313, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 22ms/step - loss: 0.1676 - accuracy: 0.9396 - val_loss: 0.1595 - val_accuracy: 0.9431 - lr: 4.1764e-05
# Epoch 29/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1686 - accuracy: 0.9399
# Epoch 29: val_accuracy improved from 0.94313 to 0.94730, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1680 - accuracy: 0.9400 - val_loss: 0.1492 - val_accuracy: 0.9473 - lr: 4.1348e-05
# Epoch 30/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.9392
# Epoch 30: val_accuracy did not improve from 0.94730
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1669 - accuracy: 0.9394 - val_loss: 0.1547 - val_accuracy: 0.9451 - lr: 4.0937e-05
# Epoch 31/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1597 - accuracy: 0.9421
# Epoch 31: val_accuracy did not improve from 0.94730
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1592 - accuracy: 0.9423 - val_loss: 0.1539 - val_accuracy: 0.9453 - lr: 4.0529e-05
# Epoch 32/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9447
# Epoch 32: val_accuracy improved from 0.94730 to 0.94833, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1563 - accuracy: 0.9448 - val_loss: 0.1448 - val_accuracy: 0.9483 - lr: 4.0126e-05
# Epoch 33/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9455
# Epoch 33: val_accuracy improved from 0.94833 to 0.95161, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.1535 - accuracy: 0.9455 - val_loss: 0.1357 - val_accuracy: 0.9516 - lr: 3.9727e-05
# Epoch 34/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9466
# Epoch 34: val_accuracy improved from 0.95161 to 0.95482, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 22ms/step - loss: 0.1501 - accuracy: 0.9466 - val_loss: 0.1271 - val_accuracy: 0.9548 - lr: 3.9331e-05
# Epoch 35/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9491
# Epoch 35: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1454 - accuracy: 0.9492 - val_loss: 0.1248 - val_accuracy: 0.9544 - lr: 3.8940e-05
# Epoch 36/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9502
# Epoch 36: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1404 - accuracy: 0.9502 - val_loss: 0.1255 - val_accuracy: 0.9541 - lr: 3.8553e-05
# Epoch 37/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1364 - accuracy: 0.9515
# Epoch 37: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1366 - accuracy: 0.9516 - val_loss: 0.1277 - val_accuracy: 0.9530 - lr: 3.8169e-05
# Epoch 38/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9533
# Epoch 38: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1326 - accuracy: 0.9535 - val_loss: 0.1303 - val_accuracy: 0.9520 - lr: 3.7789e-05
# Epoch 39/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9545
# Epoch 39: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1296 - accuracy: 0.9545 - val_loss: 0.1320 - val_accuracy: 0.9508 - lr: 3.7413e-05
# Epoch 40/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9554
# Epoch 40: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 22ms/step - loss: 0.1261 - accuracy: 0.9554 - val_loss: 0.1340 - val_accuracy: 0.9498 - lr: 3.7041e-05
# Epoch 41/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.1232 - accuracy: 0.9563
# Epoch 41: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 21ms/step - loss: 0.1230 - accuracy: 0.9564 - val_loss: 0.1354 - val_accuracy: 0.9489 - lr: 3.6672e-05
# Epoch 42/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1202 - accuracy: 0.9577
# Epoch 42: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 22ms/step - loss: 0.1202 - accuracy: 0.9577 - val_loss: 0.1364 - val_accuracy: 0.9483 - lr: 3.6307e-05
# Epoch 43/100
# 115/115 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9586
# Epoch 43: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 22ms/step - loss: 0.1177 - accuracy: 0.9586 - val_loss: 0.1370 - val_accuracy: 0.9480 - lr: 3.5946e-05
# Epoch 44/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9602
# Epoch 44: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1150 - accuracy: 0.9602 - val_loss: 0.1364 - val_accuracy: 0.9479 - lr: 3.5589e-05
# Epoch 45/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9611
# Epoch 45: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1128 - accuracy: 0.9609 - val_loss: 0.1356 - val_accuracy: 0.9484 - lr: 3.5234e-05
# Epoch 46/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.1110 - accuracy: 0.9613
# Epoch 46: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 22ms/step - loss: 0.1107 - accuracy: 0.9615 - val_loss: 0.1364 - val_accuracy: 0.9485 - lr: 3.4884e-05
# Epoch 47/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9623
# Epoch 47: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 21ms/step - loss: 0.1089 - accuracy: 0.9621 - val_loss: 0.1388 - val_accuracy: 0.9474 - lr: 3.4537e-05
# Epoch 48/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9624
# Epoch 48: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1070 - accuracy: 0.9623 - val_loss: 0.1396 - val_accuracy: 0.9468 - lr: 3.4193e-05
# Epoch 49/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9635
# Epoch 49: val_accuracy did not improve from 0.95482
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1045 - accuracy: 0.9634 - val_loss: 0.1309 - val_accuracy: 0.9505 - lr: 3.3853e-05
# Epoch 50/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9645
# Epoch 50: val_accuracy improved from 0.95482 to 0.95735, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 23ms/step - loss: 0.1013 - accuracy: 0.9645 - val_loss: 0.1145 - val_accuracy: 0.9574 - lr: 3.3516e-05
# Epoch 51/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9650
# Epoch 51: val_accuracy improved from 0.95735 to 0.96214, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0985 - accuracy: 0.9650 - val_loss: 0.1019 - val_accuracy: 0.9621 - lr: 3.3183e-05
# Epoch 52/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0959 - accuracy: 0.9659
# Epoch 52: val_accuracy improved from 0.96214 to 0.96699, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 22ms/step - loss: 0.0959 - accuracy: 0.9659 - val_loss: 0.0925 - val_accuracy: 0.9670 - lr: 3.2852e-05
# Epoch 53/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0937 - accuracy: 0.9671
# Epoch 53: val_accuracy improved from 0.96699 to 0.97013, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0936 - accuracy: 0.9672 - val_loss: 0.0852 - val_accuracy: 0.9701 - lr: 3.2525e-05
# Epoch 54/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9678
# Epoch 54: val_accuracy improved from 0.97013 to 0.97211, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0916 - accuracy: 0.9679 - val_loss: 0.0817 - val_accuracy: 0.9721 - lr: 3.2202e-05
# Epoch 55/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0906 - accuracy: 0.9686
# Epoch 55: val_accuracy improved from 0.97211 to 0.97246, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0902 - accuracy: 0.9687 - val_loss: 0.0797 - val_accuracy: 0.9725 - lr: 3.1881e-05
# Epoch 56/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.9686
# Epoch 56: val_accuracy did not improve from 0.97246
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0886 - accuracy: 0.9687 - val_loss: 0.0791 - val_accuracy: 0.9722 - lr: 3.1564e-05
# Epoch 57/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0872 - accuracy: 0.9694
# Epoch 57: val_accuracy did not improve from 0.97246
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0869 - accuracy: 0.9695 - val_loss: 0.0785 - val_accuracy: 0.9723 - lr: 3.1250e-05
# Epoch 58/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9705
# Epoch 58: val_accuracy did not improve from 0.97246
# 115/115 [==============================] - 3s 27ms/step - loss: 0.0845 - accuracy: 0.9706 - val_loss: 0.0777 - val_accuracy: 0.9725 - lr: 3.0939e-05
# Epoch 59/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9716
# Epoch 59: val_accuracy improved from 0.97246 to 0.97266, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 23ms/step - loss: 0.0825 - accuracy: 0.9716 - val_loss: 0.0768 - val_accuracy: 0.9727 - lr: 3.0631e-05
# Epoch 60/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9726
# Epoch 60: val_accuracy did not improve from 0.97266
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0809 - accuracy: 0.9726 - val_loss: 0.0766 - val_accuracy: 0.9721 - lr: 3.0327e-05
# Epoch 61/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0798 - accuracy: 0.9734
# Epoch 61: val_accuracy did not improve from 0.97266
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0795 - accuracy: 0.9735 - val_loss: 0.0764 - val_accuracy: 0.9725 - lr: 3.0025e-05
# Epoch 62/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9737
# Epoch 62: val_accuracy did not improve from 0.97266
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0784 - accuracy: 0.9738 - val_loss: 0.0765 - val_accuracy: 0.9722 - lr: 2.9726e-05
# Epoch 63/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9734
# Epoch 63: val_accuracy did not improve from 0.97266
# 115/115 [==============================] - 2s 22ms/step - loss: 0.0775 - accuracy: 0.9735 - val_loss: 0.0774 - val_accuracy: 0.9718 - lr: 2.9430e-05
# Epoch 64/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9733
# Epoch 64: val_accuracy did not improve from 0.97266
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0767 - accuracy: 0.9733 - val_loss: 0.0825 - val_accuracy: 0.9692 - lr: 2.9137e-05
# Epoch 65/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9734
# Epoch 65: val_accuracy did not improve from 0.97266
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0763 - accuracy: 0.9735 - val_loss: 0.0867 - val_accuracy: 0.9673 - lr: 2.8847e-05
# Epoch 66/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.9731
# Epoch 66: val_accuracy improved from 0.97266 to 0.97314, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 23ms/step - loss: 0.0770 - accuracy: 0.9732 - val_loss: 0.0745 - val_accuracy: 0.9731 - lr: 2.8560e-05
# Epoch 67/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0746 - accuracy: 0.9739
# Epoch 67: val_accuracy improved from 0.97314 to 0.97587, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0746 - accuracy: 0.9740 - val_loss: 0.0676 - val_accuracy: 0.9759 - lr: 2.8276e-05
# Epoch 68/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.0717 - accuracy: 0.9746
# Epoch 68: val_accuracy improved from 0.97587 to 0.97676, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 22ms/step - loss: 0.0715 - accuracy: 0.9746 - val_loss: 0.0648 - val_accuracy: 0.9768 - lr: 2.7995e-05
# Epoch 69/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0695 - accuracy: 0.9757
# Epoch 69: val_accuracy improved from 0.97676 to 0.97751, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 23ms/step - loss: 0.0693 - accuracy: 0.9757 - val_loss: 0.0639 - val_accuracy: 0.9775 - lr: 2.7716e-05
# Epoch 70/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9762
# Epoch 70: val_accuracy improved from 0.97751 to 0.97786, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0676 - accuracy: 0.9762 - val_loss: 0.0639 - val_accuracy: 0.9779 - lr: 2.7441e-05
# Epoch 71/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9768
# Epoch 71: val_accuracy improved from 0.97786 to 0.97799, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0662 - accuracy: 0.9769 - val_loss: 0.0645 - val_accuracy: 0.9780 - lr: 2.7168e-05
# Epoch 72/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9771
# Epoch 72: val_accuracy did not improve from 0.97799
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0649 - accuracy: 0.9771 - val_loss: 0.0642 - val_accuracy: 0.9779 - lr: 2.6897e-05
# Epoch 73/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9779
# Epoch 73: val_accuracy improved from 0.97799 to 0.97827, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 22ms/step - loss: 0.0638 - accuracy: 0.9780 - val_loss: 0.0640 - val_accuracy: 0.9783 - lr: 2.6630e-05
# Epoch 74/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9785
# Epoch 74: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 3s 23ms/step - loss: 0.0628 - accuracy: 0.9785 - val_loss: 0.0651 - val_accuracy: 0.9774 - lr: 2.6365e-05
# Epoch 75/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9789
# Epoch 75: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0618 - accuracy: 0.9789 - val_loss: 0.0665 - val_accuracy: 0.9768 - lr: 2.6102e-05
# Epoch 76/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9797
# Epoch 76: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0609 - accuracy: 0.9797 - val_loss: 0.0679 - val_accuracy: 0.9753 - lr: 2.5843e-05
# Epoch 77/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0604 - accuracy: 0.9800
# Epoch 77: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0603 - accuracy: 0.9800 - val_loss: 0.0690 - val_accuracy: 0.9750 - lr: 2.5585e-05
# Epoch 78/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9802
# Epoch 78: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0600 - accuracy: 0.9802 - val_loss: 0.0728 - val_accuracy: 0.9730 - lr: 2.5331e-05
# Epoch 79/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9799
# Epoch 79: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0601 - accuracy: 0.9800 - val_loss: 0.0766 - val_accuracy: 0.9713 - lr: 2.5079e-05
# Epoch 80/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9795
# Epoch 80: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 22ms/step - loss: 0.0608 - accuracy: 0.9796 - val_loss: 0.0847 - val_accuracy: 0.9676 - lr: 2.4829e-05
# Epoch 81/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0624 - accuracy: 0.9795
# Epoch 81: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 3s 22ms/step - loss: 0.0621 - accuracy: 0.9795 - val_loss: 0.0985 - val_accuracy: 0.9622 - lr: 2.4582e-05
# Epoch 82/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9780
# Epoch 82: val_accuracy did not improve from 0.97827
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0644 - accuracy: 0.9782 - val_loss: 0.0918 - val_accuracy: 0.9647 - lr: 2.4338e-05
# Epoch 83/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0700 - accuracy: 0.9750
# Epoch 83: val_accuracy improved from 0.97827 to 0.97991, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 25ms/step - loss: 0.0693 - accuracy: 0.9753 - val_loss: 0.0585 - val_accuracy: 0.9799 - lr: 2.4095e-05
# Epoch 84/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9705
# Epoch 84: val_accuracy improved from 0.97991 to 0.98155, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0753 - accuracy: 0.9705 - val_loss: 0.0537 - val_accuracy: 0.9815 - lr: 2.3856e-05
# Epoch 85/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.9708
# Epoch 85: val_accuracy improved from 0.98155 to 0.98531, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0785 - accuracy: 0.9712 - val_loss: 0.0475 - val_accuracy: 0.9853 - lr: 2.3618e-05
# Epoch 86/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9736
# Epoch 86: val_accuracy did not improve from 0.98531
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0732 - accuracy: 0.9740 - val_loss: 0.0493 - val_accuracy: 0.9842 - lr: 2.3383e-05
# Epoch 87/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9766
# Epoch 87: val_accuracy did not improve from 0.98531
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0655 - accuracy: 0.9766 - val_loss: 0.0478 - val_accuracy: 0.9851 - lr: 2.3151e-05
# Epoch 88/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9782
# Epoch 88: val_accuracy improved from 0.98531 to 0.98633, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 23ms/step - loss: 0.0631 - accuracy: 0.9783 - val_loss: 0.0459 - val_accuracy: 0.9863 - lr: 2.2920e-05
# Epoch 89/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9784
# Epoch 89: val_accuracy improved from 0.98633 to 0.98701, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0611 - accuracy: 0.9787 - val_loss: 0.0443 - val_accuracy: 0.9870 - lr: 2.2692e-05
# Epoch 90/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9794
# Epoch 90: val_accuracy improved from 0.98701 to 0.98715, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0592 - accuracy: 0.9794 - val_loss: 0.0434 - val_accuracy: 0.9872 - lr: 2.2466e-05
# Epoch 91/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9801
# Epoch 91: val_accuracy improved from 0.98715 to 0.98729, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 3s 22ms/step - loss: 0.0572 - accuracy: 0.9802 - val_loss: 0.0428 - val_accuracy: 0.9873 - lr: 2.2243e-05
# Epoch 92/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0558 - accuracy: 0.9809
# Epoch 92: val_accuracy improved from 0.98729 to 0.98756, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0554 - accuracy: 0.9811 - val_loss: 0.0421 - val_accuracy: 0.9876 - lr: 2.2022e-05
# Epoch 93/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9818
# Epoch 93: val_accuracy did not improve from 0.98756
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0538 - accuracy: 0.9820 - val_loss: 0.0418 - val_accuracy: 0.9875 - lr: 2.1802e-05
# Epoch 94/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9824
# Epoch 94: val_accuracy improved from 0.98756 to 0.98770, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0523 - accuracy: 0.9826 - val_loss: 0.0414 - val_accuracy: 0.9877 - lr: 2.1586e-05
# Epoch 95/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9832
# Epoch 95: val_accuracy did not improve from 0.98770
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0510 - accuracy: 0.9833 - val_loss: 0.0412 - val_accuracy: 0.9877 - lr: 2.1371e-05
# Epoch 96/100
# 112/115 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9836
# Epoch 96: val_accuracy improved from 0.98770 to 0.98797, saving model to /content/drive/MyDrive/model_weights.h5
# 115/115 [==============================] - 2s 21ms/step - loss: 0.0498 - accuracy: 0.9838 - val_loss: 0.0408 - val_accuracy: 0.9880 - lr: 2.1158e-05
# Epoch 97/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.0488 - accuracy: 0.9839
# Epoch 97: val_accuracy did not improve from 0.98797
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.0406 - val_accuracy: 0.9880 - lr: 2.0948e-05
# Epoch 98/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9845
# Epoch 98: val_accuracy did not improve from 0.98797
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0476 - accuracy: 0.9846 - val_loss: 0.0405 - val_accuracy: 0.9874 - lr: 2.0739e-05
# Epoch 99/100
# 113/115 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9848
# Epoch 99: val_accuracy did not improve from 0.98797
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0467 - accuracy: 0.9849 - val_loss: 0.0403 - val_accuracy: 0.9874 - lr: 2.0533e-05
# Epoch 100/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9852
# Epoch 100: val_accuracy did not improve from 0.98797
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0459 - accuracy: 0.9852 - val_loss: 0.0404 - val_accuracy: 0.9872 - lr: 2.0328e-05

# %% [markdown]
# # Model Evaluation
#
# **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the models performance.**

# %%
# CodeGrade Tag Ex4a
sns.set_theme(context='paper')

fig, ax = plt.subplots(1, 2, figsize=(15, 4))
# Plot
ax[0].plot(history.history['loss'], c='orangered', label='Training')
ax[0].plot(history.history['val_loss'], c='royalblue', label='Validation')
ax[0].set_xlabel('Number of Epochs')
ax[0].set_ylabel('Sparse Categorical Crossentropy')
ax[0].set_title('Model Loss')
ax[0].legend()

ax[1].plot(history.history['accuracy'], c='orangered', label='Training')
ax[1].plot(history.history['val_accuracy'], c='royalblue', label='Validation')
ax[1].set_xlabel('Number of Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Model Accuracy')
ax[1].legend()
plt.savefig('loss_accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# **Load the best weights from your model checkpoint, and create plots demonstrating the classification perfomnce for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %%
# CodeGrade Tag Ex4b

model.load_weights(checkpoint_filepath)
# Get true labels
valid_labels = [labels for images, labels in valid_ds]
y_true = tf.concat(valid_labels, axis=0)
# Predict labels
predictions = model.predict(valid_ds)
y_pred = np.argmax(predictions, axis=1)

# Classification report
print(classification_report(y_true, y_pred, target_names=label_dict.keys()))

# Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot heat map
diag_mask = np.eye(*cm.shape, dtype=bool)
off_diag_mask = ~diag_mask
# Create the heatmap
fig, ax = plt.subplots()
sns.heatmap(cm, mask=off_diag_mask, vmin=200, cmap='Blues', annot=True, fmt='d',
            xticklabels=label_dict.keys(), yticklabels=label_dict.keys(), ax=ax)
sns.heatmap(cm, mask=diag_mask, vmin=0, cmap='OrRd', annot=True, fmt='d',
            xticklabels=label_dict.keys(), yticklabels=label_dict.keys(), ax=ax)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix Heat Map')
plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 115/115 [==============================] - 1s 5ms/step
#               precision    recall  f1-score   support
#
#          cat       1.00      0.99      0.99      5154
#          dog       0.99      0.98      0.99      4739
#         wild       0.97      0.99      0.98      4738
#
#     accuracy                           0.99     14631
#    macro avg       0.99      0.99      0.99     14631
# weighted avg       0.99      0.99      0.99     14631

# %%
# Initialize lists to store misclassified images and their true and predicted labels
misclassified_images = []
misclassified_true_labels = []
misclassified_pred_labels = []

# Iterate over the dataset
for i, (images, labels) in enumerate(valid_ds):
    # Get predictions for the current batch
    batch_predictions = y_pred[i*len(images):(i+1)*len(images)]

    # Find misclassified indices in the current batch
    misclassified_indices = np.where(batch_predictions != labels.numpy())

    # Append misclassified images and labels
    misclassified_images.extend(images.numpy()[misclassified_indices])
    misclassified_true_labels.extend(labels.numpy()[misclassified_indices])
    misclassified_pred_labels.extend(batch_predictions[misclassified_indices])

# Plot some misclassified images
fig, axs = plt.subplots(3, 8, figsize=(15, 6))

for i, ax in enumerate(axs.flat):
    ax.imshow(np.array(misclassified_images)[i]/255.0)
    ax.set_axis_off()
    tr = list(label_dict.keys())[int(np.array(misclassified_true_labels)[i])] # get true label from label_dict
    pred = list(label_dict.keys())[int(np.array(misclassified_pred_labels)[i])] # get predicted label from label_dict
    ax.set_title(f'True: {tr}, Pred: {pred}')

plt.tight_layout()
plt.savefig('missclassified.png', dpi=300, bbox_inches='tight')
plt.show()
